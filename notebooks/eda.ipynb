# %%
import pandas as pd

# %%
df = pd.read_csv("../DS01/metadata/engine_manifest.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of     suite_id  engine_id  split  fault_id scenario_flag_string  num_rows
# 0       DS01   20270001  train         1          011110_1100       200
# 1       DS01   20270002  train         1          011110_1100       200
# 2       DS01   20270003   test         1          011110_1100       200
# 3       DS01   20270004  train         1          011110_1100       200
# 4       DS01   20270005  train         1          011110_1100       200
# ..       ...        ...    ...       ...                  ...       ...
# 195     DS01   20270196   test         1          011110_1100       200
# 196     DS01   20270197  train         1          011110_1100       200
# 197     DS01   20270198  train         1          011110_1100       200
# 198     DS01   20270199  train         1          011110_1100       200
# 199     DS01   20270200   test         1          011110_1100       200
#
# [200 rows x 6 columns]>

# %%
df.columns
# Out:
# Index(['suite_id', 'engine_id', 'split', 'fault_id', 'scenario_flag_string',
#        'num_rows'],
#       dtype='str')
